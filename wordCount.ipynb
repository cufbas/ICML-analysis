# %%
import pandas as pd

# %%
data = pd.read_csv(r'Table 1-Grid view.csv')
df = pd.DataFrame(data)
#df = df.dropna(axis=0)

# %%
df
# Out:
#      Conference    Year                               Workshop name  \
# 0           NaN     NaN                                         NaN
# 1           NaN     NaN                                         NaN
# 2           NaN     NaN                                         NaN
# 3           NaN     NaN                                         NaN
# 4       NeurIPS  2018.0                          Continual Learning
# ...         ...     ...                                         ...
# 1206       AAAI  2020.0        W21: Reinforcement Learning in Games
# 1207       AAAI  2021.0        W23: Reinforcement Learning in Games
# 1208       AAAI  2022.0  W32: Reinforcement Learning in Games (RLG)
# 1209      IJCAI  2017.0               5) Workshop on Computer Games
# 1210      IJCAI  2018.0                     Computer Games Workshop
#
#              Topic          Topic copy  confused flag Notes  \
# 0              NaN                 NaN       NaN  NaN   NaN
# ...

# %%
df.Topic.unique()
# Out:
# array([nan, 'Adaptiveness', 'Adversarial ML', 'AI for policy', 'Audio',
#        'AutoML', 'Bayesian Learning', 'Biology & Biological systems',
#        'Causality', 'Climate change', 'Compact ML', 'Competition',
#        'Computer Vision', 'Cybersecurity', 'Data', 'Decision making ',
#        'Earth Sciences', 'Economics', 'Education', 'Food', 'GANs',
#        'Generalizability', 'Generative Models',
#        'Geometric & Topological Data Analysis', 'Gradient', 'Graphs',
#        'Hardware focus', 'Healthcare', 'Human Centered AI',
#        'Humans in the loop', 'Images', 'Information Theory',
#        'Insights from neuroscience', 'Internet of Things',
#        'Interpretability', 'Knowledge-based systems', 'Language learning',
#        'mechanism design', 'Memory', 'Meta on the ML field',
#        'Meta-learning', 'ML for Computer Science ', 'ML for engineering',
#        'ML for media-art', 'Multi-agent systems', 'New frontiers',
# ...
